# %% [markdown]
# # Iris & Wine, Compare classifires (Decision Tree, naïve Bayes, k-Nearest neighbors, SVM, DNN, CNN & PNN)

# %% [markdown]
# # **Abstract**
# In this Colab from Google is shown how are the differetns measurings from the diferetns classifications for dataset like decision tree, Naive Bayes (Gaussian and Multinomial),k-Nearest neighbors, SVM and Deep Neural Networks (The best until now, but doing the correct parameters, datsets and fitting). Why do we use them and what are the Mathematics behim them.

# %% [markdown]
# # **Content**

# %% [markdown]
# ## Decission Tree
# A decision tree is non-parametric supervised learning algorithm, which is utilized for classification and regression task. It has tree structure, hirearchical, which means that has node, braches, internal nodes and leaf nodes.
#
# Image from IBM:
# ![image.png](data:image/png;base64,...)
# The most interesting Algorithms for DEsicion Tree are the next:
# 1. ID3: This algorithm leverages entropy and information gain as metrics to evalute candidate splits.
# 2. C4.5: Is developed by Quinlan too. It can use information gain or gain ratios to evaluate split points within the decision trees.
# 3. CART: "Classification and regression Trees", introduced by Leo Breiman. This algorithm typically utilizes Dini impurity to identify the ideal attribute to split on. Measuring how often a randmly chosen attribute is misclassified. When evaluating using Gini impurity, a lower value is more ideal.
# How do we get retroalimention to use the best option?
# We use entropy and Information Gain.
# Entropy is a cocpt more use in stems from information theory, which measures the impurity of the same values. It is defined by:
#
# $$
# \begin{equation}
# Entropy(S) = -\sum_{c∈C} (c)log_2p(c)
# \end{equation}
# $$
# Where:
# - S represents the data set that entropy is calculated
# - c represents the classes in set, S
# - p(c) represents the proportion of data points that belong to class c to the number of total data points in set, S
#
# Usually the entropy values can fall between 0 and 1. If all samples in data set, S, belong to one class, the entropy will be equal to 0. If half of the samples are classified as one class and the other half are in another class, entropy will be at its highest at 1. In order to select the best feature to split on and find the optimal decision tree, the attribute with the smallest amount of entropy should be used. Information gain represents the difference in entropy before and after a split on a given attribute. The attribute with the highest information gain will produce the best split as it is doing the best job at classifying the training data according to its target classification.
#
# The principal point that must be consider are the nest ones:
# - Advantages
#   * Easy to interpret
#   * Little to no data preparation requiered
#   * More flexible
# - Disadvantages
#   * Prone to overfiting
#   * High variance estimators
#   * More costly

# %% [markdown]
# ## Naïve Bayes
# Is a supervised machine learning algorithm, which is used for classifiaction task, like text classification. It is part too for generative algorithms, this means that the model seeks to model the distribution of inputs of a given class or category but the algorithm does not learn which features are most important to differiantiate between classes. The algorithm is also know as a probabilistic classifier since it is based on Baye's Theorem. The toerem (that is known as Baye's Rule also), allows us to "invert" conditional probabilities. THe conditional probabilities represent the probability of and event given us information that some other event has already occured and is represented in the next formula:
#
# $$
# \begin{equation}
# P(Y|X) = P(X and Y)/ P(x)
# \end{equation}
# $$
#
# The theorem is distinguished for using sequuentians event, that means that the additional information later acquired impacts the initial probability. The prior probability is an initial probability of a certain event before it is contextualized under a certain condition, or the margianl probability. The probability that is posterior is the ones of an event after observing a piece of data. The theorem assumes that predictiors are conditionally independent, or underelated to any of the other feature in the model. It also assumes that all features contribute equally to the outcome.
# One of the differnte ways to evaluate the model is to plot a confusion matrix, which will plot the actual and predicted values within a matrix. Rows usually represent actual values and while columns the predicted values.
#
# Image from IBM:
# ![image.png](data:image/png;base64,...)
#
# There are different types of models to classifiers, there are some:
# - Gaussian Naïve Bayes (GaussianNB)
# - Multinomial Naïve Bayes (MultinomialNB)
# - Bernoulli Naïve Bayes (BernoulliNB)
#
# And the principal advantages and disadvantages from the Naïve Bayes are the next ones:
# - Advantages
#   * Less Complex
#   * Scales well
#   * Can handle high-dimensional data
# - Disadvantages
#   * Subject to Zero frequency
#   * Unrealistic core assumption
#
# Some of the principal applications are the next:
# - Spam filtering
# - Document classification
# - Sentiment analysis
# - Mental state predictions

# %% [markdown]
# ## KNN algorithm
# Is an algorithm which is non-parametric, supervised leaning classifier, which is uses proximity to make classifications or predictions from a group or individual points of data. It is one of the most popular and simplest classification and regression classifiers used in machine learning.
# Is used typically as a classification algorithm, working off the assumption that siminlar ponts can be found near one another.
# The algorithm use the "plurality voting" that means that is not necesary the "majority vote" (that means that requieres >50% of the 'votes') meanwhile the plurality voting says that take the resolt as the maximum value in the group for example from [25%-A,10%-B,5%-C,5%-D,3%-E,2%-F,20%-G,10%-H,20%-I]. The value that the algorithm consider to classify the group as an 'A' is the 25% cause it is the maximum value from the group.
#
# Image from IBM:
# ![image.png](data:image/png;base64,...)
# The main distinction here is that classification is used for discrete values, whereas regression is used with continuous ones. However, before a classification can be made, the distance must be defined. Euclidean distance is most commonly used, which we’ll delve into more below.
# It's also worth noting that the KNN algorithm is also part of a family of “lazy learning” models, meaning that it only stores a training dataset versus undergoing a training stage. This also means that all the computation occurs when a classification or prediction is being made. Since it heavily relies on memory to store all its training data, it is also referred to as an instance-based or memory-based learning method.
# What are the metrics that we need to consider?
# - Determinate distance metrics
# Determinate which data points are the closest to a given query point, the distance between them will calculate. These distance metrics help to form decision boundaries. The most commonly distance measure are
# 1. Euclidean distance (p=2). Measured be the next formula:
#
# $$
# \begin{equation}
# d(x,y) = \sqrt {\sum_{i=1}^{n}(yi-xi)^2}
# \end{equation}
# $$
#
# 2. Manhattan distance (p=1). Measured be the next formula:
#
# $$
# \begin{equation}
# d(x,y) = (\sum_{i=1}^{m}|Xi-Yi|)
# \end{equation}
# $$
#
# 3. Minkowski distance (p=1). Measured be the next formula:
#
# $$
# \begin{equation}
# Minkowski distance = (\sum_{i=1}^{n}|Xi-Yi|)^(1/p)
# \end{equation}
# $$
#
# 4. Hammming distance (p=1). Measured be the next formula:
#
# $$
# \begin{equation}
# DH = (\sum_{i=1}^{k}|Xi-Yi|)
# \end{equation}
# $$
#
# Where:
# x=y   D=0
# x!=y  D!=1
#
#
# The value K in k-NN determinates how many neighborgs will be checked to determine the classification of a specific query point. For example, if k=1, the instance will be assigned to the same class as its single nearest neighbor. Defining k can be a balancing act as different values can lead to overfitting or underfitting. Lower values of k can have high variance, but low bias, and larger values of k may lead to high bias and lower variance. The choice of k will largely depend on the input data as data with more outliers or noise will likely perform better with higher values of k.
#
# Applications:
# - Data processing
# - Recommendation Engines
# - Finance
# - Healthcare
# - Pattern Recognition
#
# The principal Advantages and disadvantages are the next ones:
# * Advantages
#   - Easy to implement
#   - Adapts easily
#   - Few hyperparameters
#
# * Disadvantages
#   - Does not scale well
#   - Curse of dimensionality
#   - Prone to overfitting

# %% [markdown]
# ## Support Vector Machine (SVM)
# Is a supervising learning algorithm used in machine learning to solve classification and regression tasks. This type of algorithms are particularly good at solving binary classification problems, where is requiered classifying the elements of data set into two groups.
# The aim of support vector machine algorithm is to find the best possible line that separates the data points of different data classes. THis is called as hyperplane when working in high-dimensional feature spaces. The principal idea is to maximize the margin, which is the distance between the hyperplane and the closest data points of each category, which helps easy to distinguish data classes.
# SVMs are useful for analyzing complex data that can't be separated by a simple straight line. Whit nonlinenar SVMs, they do this by using mathematicals that transform data into higher-dimensional space which makes easier find boundary.
# The SVMs uses a kernel function to avoid the calcutation of each coordinate from the trasnformed space, the evalueates vectors and avoid handling expensive computations.
# Sometimes an linear separable line is not the best option so we could use differente types of kernel functions, linear kernels, polynomials kernel or radial basis fuction (RBF) kernel. These kernels enable SVMs to effectively captura complex realtionships and pattarns in the data.
# The best kernel function for a a particular problem depends on the characteristics of the data.
#
# Image from DataCamp.com:
#
# ![image.png](data:image/png;base64,...)
#
# Some of the most popular kernel functions for SVMs are:
# - Linear kernel
# - Polynomial kernel
# - RBF kernel
# - Sigmoid kernel
#
# The more powerful kernel functions, such as the RBF kernel, can achieve higher accuracy than the simpler kernel functions, but they also require more data and computation time to train the SVM algorithm. But this is becoming less of an issue due to technological advances. The best of the algorith is that it could classify new data that as been unseen and determining which side of the decision boundary they could fall.
#
# The types of support vector machines are:
#
# - Linear SVM
# - Nonlinear SVM
#
# The principal advantages and disadvantages are:
# - Advantages
#   * Effective in high-dimesional spaces
#   * Resistant to overfitting
#   * Versatile
#   * Effective in cases of limited data
#   * Ability to handle nonlinear data
# - Disadvantages
#   * Computationally intensive
#   * Sensitive
#   * Lack of probabilistic outputs
#   * Difficulty in interpreting complex models
#   * Scalability issues

# %% [markdown]
# ## CNN, Convolutional Neuronal Networks
# The CNN are most commonly use for image recognitition. The principal topic is the part of the Convolution that is a mathematical operation on two functions that at the end produced a thrid function that expresses how the first shape is modified by other.
#
# As others models, the CNN have layers that have multiple neurons in each one. Usually the first Layer extract basic features, then the next layer detects more complex feautures, and do the same for the next layers. The problem is that these Neural Networks need cover in the datasets all the possible ways that could happend with the classification, for example in visual recognition, need all the possible angles and differetn lights settings.
#
# ![image.png](data:image/png;base64,...)
#
# Image from Analytics Vidhya.
#
# At the end they work similar to DNN, have layers, these layers extract information from the datasets, the layers needs an output to classify what they are getting.

# %% [markdown]
# ## PNN, Probabilistic Neural Network / Bayesina Networks
# They uses Bayes theorem to solve complex problems. The PNN is a type of a Neural Network which are use comontly for cassification and pattern recognition applications. Helps to reduces the number of incorrect classifications.
#
# ![image.png](data:image/png;base64,...)
#
# Image from Paper by Specht 1990
#
# The PNN aims to build an ANN using methods from probability theory like Bayesian classification & other estimators for pdf. The application of kernel functions for discriminant analysis and pattern recognition gave rise to the widespread use of PNN.

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris, load_wine
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Sequential, Model, model_from_json
from keras.models import Sequential
from keras.utils import to_categorical
#from google.colab import filesLinear Separator
from google.colab import files
from IPython.display import HTML
import sys, os
import pandas as pd
from sklearn.metrics import confusion_matrix
import itertools
from sklearn import datasets, svm
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.svm import SVC
import tensorflow as tf
from pandas import read_csv
from numpy import array
from keras.optimizers import Adam

# %% [markdown]
# ## Wine

# %%
wine = datasets.load_wine() #Load data

# %%
data=wine['data']
data #Show the numerical data

# %%
features_names=wine['feature_names']#Load data about the rows and columns
cultivars = np.array(['Cultivar{}'.format(cl) for cl in wine['target']])#Load cultivar information about each wine
wine_names = np.array(['Wine{}'.format(i) for i in range(data.shape[0])])# Create "nice names" for each row
data = pd.DataFrame(data,columns=features_names,index=wine_names)
data.all()#Check all the columns
#data['total_phenols']

# %%
# !pip install scprep

# %%
import scprep
from scipy.spatial.distance import pdist, squareform
import seaborn as sns
data_scaled = StandardScaler().fit_transform(data)
sns.clustermap(data_scaled, xticklabels=data.columns, row_colors=plt.cm.tab10(wine['target']))
#See the dataset of wine

# %%
# !pip install pydotplus

# %% [markdown]
# ### Desicion Tree

# %%
import pandas as pd
import pydotplus #pip install pydotplus
from sklearn.tree import export_graphviz
from sklearn.tree import DecisionTreeClassifier
import numpy as np
from sklearn import tree
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### 50% testing & 50% training

# %%
# Convert dataset to a frame
df_wine = pd.DataFrame(wine.data, columns=wine.feature_names)
df_wine['target'] = wine.target
#divide and train
X_train, X_test, y_train, y_test = train_test_split(df_wine.drop('target', axis=1), df_wine['target'], test_size=0.5, random_state=0)
# Define decision tree
clf_tree = tree.DecisionTreeClassifier()#criterion= 'entropy'
# Train model
clf_tree.fit(X_train, y_train)
# Predict
y_pred_tree = clf_tree.predict(X_test)
#Calculate accuracy
accuracy_tree = accuracy_score(y_test, y_pred_tree)
print("Tree accuracy with 50% training and 50% testing:", accuracy_tree)

# %% [markdown]
# #### 20% testing & 80% training

# %%
# Convert dataset to a frame
df_wine = pd.DataFrame(wine.data, columns=wine.feature_names)
df_wine['target'] = wine.target
#divide and train
X_train, X_test, y_train, y_test = train_test_split(df_wine.drop('target', axis=1), df_wine['target'], test_size=0.2, random_state=0)
# Define decision tree
clf_tree = tree.DecisionTreeClassifier()#criterion= 'entropy'
# Train model
clf_tree.fit(X_train, y_train)
# Predict
y_pred_tree = clf_tree.predict(X_test)
#Calculate accuracy
accuracy_tree = accuracy_score(y_test, y_pred_tree)
print("Tree accuracy with 80% training and 20% testing:", accuracy_tree)

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### 20% Test & 80% Train

# %%
# Convert to Pandas DataSet
df_wine = pd.DataFrame(wine.data, columns=wine.feature_names)
df_wine['target'] = wine.target
X_train, X_test, y_train, y_test = train_test_split(df_wine.drop('target', axis=1), df_wine['target'], test_size=0.2, random_state=0)
model_gnb = GaussianNB() # Gaussian Naive Bayes
model_mnb = MultinomialNB() # Multinomial Naive Bayes
# Train models
model_gnb.fit(X_train, y_train)
model_mnb.fit(X_train, y_train)
# Predict
y_pred_gnb = model_gnb.predict(X_test)
y_pred_mnb = model_mnb.predict(X_test)
# Calculate Prediction
accuracy_gnb = accuracy_score(y_test, y_pred_gnb)
accuracy_mnb = accuracy_score(y_test, y_pred_mnb)
print("Prediction of Gaussian Naive Bayes:", accuracy_gnb)
print("Prediction of Multinomial Naive Bayes :", accuracy_mnb)

# %% [markdown]
# #### 50% Test & 50% Train

# %%
# Convert to Pandas DataSet
df_wine = pd.DataFrame(wine.data, columns=wine.feature_names)
df_wine['target'] = wine.target
X_train, X_test, y_train, y_test = train_test_split(df_wine.drop('target', axis=1), df_wine['target'], test_size=0.5, random_state=0)
model_gnb = GaussianNB() # Gaussian Naive Bayes
model_mnb = MultinomialNB() # Multinomial Naive Bayes
# Train models
model_gnb.fit(X_train, y_train)
model_mnb.fit(X_train, y_train)
# Predict
y_pred_gnb = model_gnb.predict(X_test)
y_pred_mnb = model_mnb.predict(X_test)
# Calculate Prediction
accuracy_gnb = accuracy_score(y_test, y_pred_gnb)
accuracy_mnb = accuracy_score(y_test, y_pred_mnb)
print("Prediction of Gaussian Naive Bayes:", accuracy_gnb)
print("Prediction of Multinomial Naive Bayes :", accuracy_mnb)

# %% [markdown]
# ###  k-Nearest neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### 20% Test & 80% Train

# %%
# Convert the data and target labels to separate variables
X = wine.data
y = wine.target
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# Define the kNN model with k = 5. the best 1-10
knn_model = KNeighborsClassifier(n_neighbors=5)
# Train the model
knn_model.fit(X_train, y_train)
# Predict the labels for the test set
y_pred = knn_model.predict(X_test)
# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of kNN model:", accuracy)

# %% [markdown]
# #### 50% Test & 50% Train

# %%
# Convert the data and target labels to separate variables
X = wine.data
y = wine.target
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
# Define the kNN model with k = 5. the best 1-10
knn_model = KNeighborsClassifier(n_neighbors=5)
# Train the model
knn_model.fit(X_train, y_train)
# Predict the labels for the test set
y_pred = knn_model.predict(X_test)
# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of kNN model:", accuracy)

# %% [markdown]
# ### SVM Exercise

# %% [markdown]
# #### 50% Test & 50% Train

# %%
X = wine.data
y = wine.target

X = X[y != 0, :2]
y = y[y != 0]

n_sample = len(X)

np.random.seed(0)
order = np.random.permutation(n_sample)
X = X[order]
y = y[order].astype(float)

X_train = X[: int(0.5 * n_sample)]
y_train = y[: int(0.5 * n_sample)]
X_test = X[int(0.5 * n_sample) :]
y_test = y[int(0.5 * n_sample) :]

# fit the model
for kernel in ("linear", "rbf", "poly"):
    clf = svm.SVC(kernel=kernel, gamma=10)
    clf.fit(X_train, y_train)

    plt.figure()
    plt.clf()
    plt.scatter(
        X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired, edgecolor="k", s=20
    )

    # Circle out the test data
    plt.scatter(
        X_test[:, 0], X_test[:, 1], s=80, facecolors="none", zorder=10, edgecolor="k"
    )

    plt.axis("tight")
    x_min = X[:, 0].min()
    x_max = X[:, 0].max()
    y_min = X[:, 1].min()
    y_max = X[:, 1].max()

    XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
    Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(XX.shape)
    plt.pcolormesh(XX, YY, Z > 0, cmap=plt.cm.Paired)
    plt.contour(
        XX,
        YY,
        Z,
        colors=["k", "k", "k"],
        linestyles=["--", "-", "--"],
        levels=[-0.5, 0, 0.5],
    )

    plt.title(kernel)
plt.show()

# %% [markdown]
# #### 20% Test & 80% Train

# %%
X = wine.data
y = wine.target

X = X[y != 0, :2]
y = y[y != 0]

n_sample = len(X)

np.random.seed(0)
order = np.random.permutation(n_sample)
X = X[order]
y = y[order].astype(float)

# Define el tamaño del entrenamiento (80%)
X_train = X[: int(0.8 * n_sample)]
y_train = y[: int(0.8 * n_sample)]

# Define el tamaño de la prueba (20%)
X_test = X[int(0.8 * n_sample) : int(1.0 * n_sample)]
y_test = y[int(0.8 * n_sample) : int(1.0 * n_sample)]

# Entrena el modelo para cada kernel
for kernel in ("linear", "rbf", "poly"):
    clf = SVC(kernel=kernel, gamma=10)
    clf.fit(X_train, y_train)

    # Visualización del modelo
    plt.figure()
    plt.clf()
    plt.scatter(
        X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired, edgecolor="k", s=20
    )

    # Resalta los datos de prueba
    plt.scatter(
        X_test[:, 0], X_test[:, 1], s=80, facecolors="none", zorder=10, edgecolor="k"
    )

    plt.axis("tight")
    x_min = X[:, 0].min()
    x_max = X[:, 0].max()
    y_min = X[:, 1].min()
    y_max = X[:, 1].max()

    XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
    Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])

    # Muestra la decisión del modelo
    Z = Z.reshape(XX.shape)
    plt.pcolormesh(XX, YY, Z > 0, cmap=plt.cm.Paired)
    plt.contour(
        XX,
        YY,
        Z,
        colors=["k", "k", "k"],
        linestyles=["--", "-", "--"],
        levels=[-0.5, 0, 0.5],
    )

    plt.title(kernel)

plt.show()

# %% [markdown]
# ### DNN

# %% [markdown]
# #### 50% training & 50% testing

# %%
# Load the wine dataset
wine = datasets.load_wine()
X = wine.data
y = wine.target.reshape(-1, 1)

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Encode labels into one-hot encoding
encoder = OneHotEncoder(sparse=False)
y_onehot = encoder.fit_transform(y)

# Split the dataset into training and testing (50% each)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_onehot, test_size=0.5, random_state=42)

# Create the DNN model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X.shape[1],)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(len(wine.target_names), activation='softmax')  # Number of classes in the wine dataset, the classes are the number of exits
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss on test set: {loss}')
print(f'Accuracy on test set: {accuracy}')

# %% [markdown]
# #### 80% training & 20% testing

# %%
# Load the wine dataset
wine = datasets.load_wine()
X = wine.data
y = wine.target.reshape(-1, 1)

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Encode labels into one-hot encoding
encoder = OneHotEncoder(sparse=False)
y_onehot = encoder.fit_transform(y)

# Split the dataset into training and testing (20%)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_onehot, test_size=0.2, random_state=42)

# Create the DNN model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X.shape[1],)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(len(wine.target_names), activation='softmax')  # Number of classes in the wine dataset, the classes are the number of exits
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss on test set: {loss}')
print(f'Accuracy on test set: {accuracy}')

# %% [markdown]
# ### CNN

# %% [markdown]
# #### 50% Testing & 50% Training

# %%
# Load the wine dataset
wine_data = datasets.load_wine()

x = wine_data.data
y_ = wine_data.target.reshape(-1, 1)

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5)

# Build the model
model = Sequential()

model.add(Dense(10, input_shape=(13,), activation='relu', name='Dense-1'))  # Adjust input shape
model.add(Dense(10, activation='relu', name='Dense-2'))
model.add(Dense(len(wine_data.target_names), activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary:')
print(model.summary())

# Train the model
model.fit(X_train, y_train, verbose=2, batch_size=4, epochs=1000)

# Test on unseen data
results = model.evaluate(X_test, y_test)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))

# %%
# Suponiendo que ya has entrenado el modelo y obtenido las predicciones
def model_matrix(model):
  y_pred = model.predict(X_test)
  y_pred_classes = np.argmax(y_pred, axis=1)
  y_true_classes = np.argmax(y_test, axis=1)

  # Crear la matriz de confusión
  conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

  # Graficar la matriz de confusión
  plt.figure(figsize=(8, 6))
  plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
  plt.title("Matriz de Confusión")
  plt.colorbar()

  class_names = wine_data.target_names
  tick_marks = np.arange(len(class_names))
  plt.xticks(tick_marks, class_names, rotation=45)
  plt.yticks(tick_marks, class_names)

  for i in range(len(class_names)):
      for j in range(len(class_names)):
          plt.text(j, i, str(conf_matrix[i, j]), ha='center', va='center')

  plt.xlabel("Clase Predicha")
  plt.ylabel("Clase Real")
  plt.show()

# %%
model_matrix(model)

# %% [markdown]
# #### 20% Testing & 80% Training

# %%
# Load the wine dataset
wine_data = datasets.load_wine()

x = wine_data.data
y_ = wine_data.target.reshape(-1, 1)

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# Build the model
model = Sequential()

model.add(Dense(10, input_shape=(13,), activation='relu', name='Dense-1'))  # Adjust input shape
model.add(Dense(10, activation='relu', name='Dense-2'))
model.add(Dense(len(wine_data.target_names), activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary:')
print(model.summary())

# Train the model
model.fit(X_train, y_train, verbose=2, batch_size=4, epochs=1000)

# Test on unseen data
results = model.evaluate(X_test, y_test)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))

# %%
model_matrix(model)

# %% [markdown]
# ### PNN

# %% [markdown]
# #### 50% Testing & 50% Training

# %%
wine = load_wine();
data = pd.DataFrame(wine.data, columns=wine.feature_names)

# %%
# Standardise input and split into train and test sets
data['target'] = wine.target
X = data.drop(columns='target',axis=1);
Y = data[['target']]
scaler = StandardScaler();
X_scaled = scaler.fit_transform(X);

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.5,random_state=12);

# %%
uniform = lambda x,b: (np.abs(x/b) <= 1) and 1/2 or 0
triangle = lambda x,b: (np.abs(x/b) <= 1) and  (1 - np.abs(x/b)) or 0
gaussian = lambda x,b: (1.0/np.sqrt(2*np.pi))* np.exp(-.5*(x/b)**2)
laplacian = lambda x,b: (1.0/(2*b))* np.exp(-np.abs(x/b))
epanechnikov = lambda x,b: (np.abs(x/b)<=1) and ((3/4)*(1-(x/b)**2)) or 0

# %%
def pattern_layer(inp,kernel,sigma):
  k_values=[];
  for i,p in enumerate(X_train.values):
    edis = np.linalg.norm(p-inp); #find eucliden distance
    k = kernel(edis,sigma); #pass values of euclidean dist and
    #smoothing parameter to kernel function
    k_values.append(k);
  return k_values;

# %%
def summation_layer(k_values,Y_train,class_counts):
  # Summing up each value for each class and then averaging
  summed =[0,0,0];
  for i,c in enumerate(class_counts):
    val = (Y_train['target']==class_counts.index[i]).values;
    k_values = np.array(k_values);
    summed[i] = np.sum(k_values[val]);


  avg_sum = list(summed/Y_train.value_counts());
  return avg_sum

# %%
def output_layer(avg_sum,class_counts):
  maxv = max(avg_sum);
  label = class_counts.index[avg_sum.index(maxv)][0];

  return label

# %%
## Bringing all layers together under PNN function

def pnn(X_train,Y_train,X_test,kernel,sigma):
  # Initialising variables
  class_counts = Y_train.value_counts()
  labels=[];
  #Passing each sample observation
  for s in X_test.values:
    k_values = pattern_layer(s,kernel,sigma);
    avg_sum = summation_layer(k_values,Y_train,class_counts);
    label = output_layer(avg_sum,class_counts);
    labels.append(label);
  print('Labels Generated for bandwidth:',sigma);
  return labels;

# %%
#Candidate Kernels
kernels = ['Gaussian','Triangular','Epanechnikov'];
sigmas = [0.05,0.5,0.8,1,1.2];

results = pd.DataFrame(columns=['Kernel','Smoothing Param','Accuracy','F1-Score']);
for k in kernels:
  if k=='Gaussian':
    k_func = gaussian;
  elif k=='Triangular':
    k_func = triangle;
  else:
    k_func = epanechnikov;

  for b in sigmas:
    pred = pnn(X_train,Y_train,X_test,k_func,b);
    accuracy = accuracy_score(Y_test.values,pred);
    f1= f1_score(Y_test.values,pred,average='weighted')
    results.loc[len(results.index)]=[k,b,accuracy,f1];
# Out:
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.subplot(121)
sns.lineplot(y=results['Accuracy'],x=results['Smoothing Param'],hue=results['Kernel']);
plt.title('Accuracy for Different Kernels',loc='right');

plt.subplot(122)
sns.lineplot(y=results['F1-Score'],x=results['Smoothing Param'],hue=results['Kernel']);
plt.title('F1-Score for Different Kernels',loc='left');

plt.show()

# %% [markdown]
# #### 20% Testing & 80% Training

# %%
# Standardise input and split into train and test sets
data['target'] = wine.target
X = data.drop(columns='target',axis=1);
Y = data[['target']]
scaler = StandardScaler();
X_scaled = scaler.fit_transform(X);

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.8,random_state=12);

# %%
#Candidate Kernels
kernels = ['Gaussian','Triangular','Epanechnikov'];
sigmas = [0.05,0.5,0.8,1,1.2];

results = pd.DataFrame(columns=['Kernel','Smoothing Param','Accuracy','F1-Score']);
for k in kernels:
  if k=='Gaussian':
    k_func = gaussian;
  elif k=='Triangular':
    k_func = triangle;
  else:
    k_func = epanechnikov;

  for b in sigmas:
    pred = pnn(X_train,Y_train,X_test,k_func,b);
    accuracy = accuracy_score(Y_test.values,pred);
    f1= f1_score(Y_test.values,pred,average='weighted')
    results.loc[len(results.index)]=[k,b,accuracy,f1];
# Out:
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.subplot(121)
sns.lineplot(y=results['Accuracy'],x=results['Smoothing Param'],hue=results['Kernel']);
plt.title('Accuracy for Different Kernels',loc='right');

plt.subplot(122)
sns.lineplot(y=results['F1-Score'],x=results['Smoothing Param'],hue=results['Kernel']);
plt.title('F1-Score for Different Kernels',loc='left');

plt.show()

# %% [markdown]
# ## Iris

# %%
iris = datasets.load_iris()

# %%
df_iris = pd.DataFrame(iris.data, columns=iris.feature_names)
df_iris['target'] = iris.target
iris

# %%
import scprep
from scipy.spatial.distance import pdist, squareform
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Carga el dataset de iris
iris = load_iris()
data = iris.data
target = iris.target

# Estandariza los datos
data_scaled = StandardScaler().fit_transform(data)

# Crea el clustermap
sns.clustermap(
    data_scaled,
    xticklabels=iris.feature_names,  # Usa los nombres de las características de iris
    row_colors=plt.cm.tab10(target),  # Mapea los colores a las clases de iris
)
plt.show()

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# #### 20% Test & 80% Train

# %%
X_train, X_test, y_train, y_test = train_test_split(df_iris.drop('target', axis=1), df_iris['target'], test_size=0.2, random_state=0)
# Model
clf_tree = tree.DecisionTreeClassifier(random_state=0)
# Train
clf_tree.fit(X_train, y_train)
# Predict
y_pred_tree = clf_tree.predict(X_test)
# Predict
accuracy_tree = accuracy_score(y_test, y_pred_tree)
print("Predict Decision Tree:", accuracy_tree)

# %% [markdown]
# #### 50% Test & 50% Train

# %%
X_train, X_test, y_train, y_test = train_test_split(df_iris.drop('target', axis=1), df_iris['target'], test_size=0.5, random_state=0)
# Model
clf_tree = tree.DecisionTreeClassifier(random_state=0)
# Train
clf_tree.fit(X_train, y_train)
# Predict
y_pred_tree = clf_tree.predict(X_test)
# Predict
accuracy_tree = accuracy_score(y_test, y_pred_tree)
print("Predict Decision Tree:", accuracy_tree)

# %%
from sklearn import tree, naive_bayes, neighbors

# %% [markdown]
# ### Naive Bayes

# %% [markdown]
# #### 20% Test & 80% Train

# %%
X_train, X_test, y_train, y_test = train_test_split(df_iris.drop('target', axis=1), df_iris['target'], test_size=0.2, random_state=0)
# Models
model_gnb = naive_bayes.GaussianNB()
model_mnb = naive_bayes.MultinomialNB()
# Train
model_gnb.fit(X_train, y_train)
model_mnb.fit(X_train, y_train)
# Predict
y_pred_gnb = model_gnb.predict(X_test)
y_pred_mnb = model_mnb.predict(X_test)
# Predict
accuracy_gnb = accuracy_score(y_test, y_pred_gnb)
accuracy_mnb = accuracy_score(y_test, y_pred_mnb)
print("Naive Bayes Gaussiano:", accuracy_gnb)
print("Naive Bayes Multinomial:", accuracy_mnb)

# %% [markdown]
# #### 50% Test & 50% Train

# %%
X_train, X_test, y_train, y_test = train_test_split(df_iris.drop('target', axis=1), df_iris['target'], test_size=0.5, random_state=0)
# Models
model_gnb = naive_bayes.GaussianNB()
model_mnb = naive_bayes.MultinomialNB()
# Train
model_gnb.fit(X_train, y_train)
model_mnb.fit(X_train, y_train)
# Predict
y_pred_gnb = model_gnb.predict(X_test)
y_pred_mnb = model_mnb.predict(X_test)
# Predict
accuracy_gnb = accuracy_score(y_test, y_pred_gnb)
accuracy_mnb = accuracy_score(y_test, y_pred_mnb)
print("Naive Bayes Gaussiano:", accuracy_gnb)
print("Naive Bayes Multinomial:", accuracy_mnb)

# %% [markdown]
# ###  k-Nearest neighbors

# %% [markdown]
# #### 20% Test & 80% Train

# %%
X_train, X_test, y_train, y_test = train_test_split(df_iris.drop('target', axis=1), df_iris['target'], test_size=0.2, random_state=0)
# Model
knn_model = neighbors.KNeighborsClassifier(n_neighbors=5)
# Train
knn_model.fit(X_train, y_train)
# Predict
y_pred_knn = knn_model.predict(X_test)
# Accuracy
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print("Predict KNN:", accuracy_knn)

# %% [markdown]
# #### 50% Test & 50% Train

# %%
X_train, X_test, y_train, y_test = train_test_split(df_iris.drop('target', axis=1), df_iris['target'], test_size=0.5, random_state=0)
# Model
knn_model = neighbors.KNeighborsClassifier(n_neighbors=5)
# Train
knn_model.fit(X_train, y_train)
# Predict
y_pred_knn = knn_model.predict(X_test)
# Accuracy
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print("Predict KNN:", accuracy_knn)

# %% [markdown]
# ### SVM Exercise

# %% [markdown]
# #### 50% Trainig & 50% Testing

# %%
X = iris.data
y = iris.target

X = X[y != 0, :2]
y = y[y != 0]

n_sample = len(X)

np.random.seed(0)
order = np.random.permutation(n_sample)
X = X[order]
y = y[order].astype(float)

X_train = X[: int(0.5 * n_sample)]
y_train = y[: int(0.5 * n_sample)]
X_test = X[int(0.5 * n_sample) :]
y_test = y[int(0.5 * n_sample) :]

# fit the model
for kernel in ("linear", "rbf", "poly"):
    clf = svm.SVC(kernel=kernel, gamma=10)
    clf.fit(X_train, y_train)

    plt.figure()
    plt.clf()
    plt.scatter(
        X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired, edgecolor="k", s=20
    )

    # Circle out the test data
    plt.scatter(
        X_test[:, 0], X_test[:, 1], s=80, facecolors="none", zorder=10, edgecolor="k"
    )

    plt.axis("tight")
    x_min = X[:, 0].min()
    x_max = X[:, 0].max()
    y_min = X[:, 1].min()
    y_max = X[:, 1].max()

    XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
    Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(XX.shape)
    plt.pcolormesh(XX, YY, Z > 0, cmap=plt.cm.Paired)
    plt.contour(
        XX,
        YY,
        Z,
        colors=["k", "k", "k"],
        linestyles=["--", "-", "--"],
        levels=[-0.5, 0, 0.5],
    )

    plt.title(kernel)
plt.show()

# %% [markdown]
# #### 80% Trainig & 20% Testing

# %%
X = iris.data
y = iris.target

X = X[y != 0, :2]
y = y[y != 0]

n_sample = len(X)

np.random.seed(0)
order = np.random.permutation(n_sample)
X = X[order]
y = y[order].astype(float)

# Define el tamaño del entrenamiento (80%)
X_train = X[: int(0.8 * n_sample)]
y_train = y[: int(0.8 * n_sample)]

# Define el tamaño de la prueba (20%)
X_test = X[int(0.8 * n_sample) : int(1.0 * n_sample)]
y_test = y[int(0.8 * n_sample) : int(1.0 * n_sample)]

# Entrena el modelo para cada kernel
for kernel in ("linear", "rbf", "poly"):
    clf = SVC(kernel=kernel, gamma=10)
    clf.fit(X_train, y_train)

    # Visualización del modelo
    plt.figure()
    plt.clf()
    plt.scatter(
        X[:, 0], X[:, 1], c=y, zorder=10, cmap=plt.cm.Paired, edgecolor="k", s=20
    )

    # Resalta los datos de prueba
    plt.scatter(
        X_test[:, 0], X_test[:, 1], s=80, facecolors="none", zorder=10, edgecolor="k"
    )

    plt.axis("tight")
    x_min = X[:, 0].min()
    x_max = X[:, 0].max()
    y_min = X[:, 1].min()
    y_max = X[:, 1].max()

    XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
    Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])

    # Muestra la decisión del modelo
    Z = Z.reshape(XX.shape)
    plt.pcolormesh(XX, YY, Z > 0, cmap=plt.cm.Paired)
    plt.contour(
        XX,
        YY,
        Z,
        colors=["k", "k", "k"],
        linestyles=["--", "-", "--"],
        levels=[-0.5, 0, 0.5],
    )

    plt.title(kernel)

plt.show()

# %% [markdown]
# ### DNN

# %% [markdown]
# #### 50% training & 50% testing

# %%
# Load the iris dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Encode labels into one-hot encoding
encoder = OneHotEncoder(sparse=False)
y_onehot = encoder.fit_transform(y)

# Split the dataset into training and testing (50% each)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_onehot, test_size=0.5, random_state=42)

# Create the DNN model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # 3 classes in the iris dataset
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss on test set: {loss}')
print(f'Accuracy on test set: {accuracy}')

# %% [markdown]
# #### 80% training & 20% Testing

# %%
# Load the iris dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Encode labels into one-hot encoding
encoder = OneHotEncoder(sparse=False)
y_onehot = encoder.fit_transform(y)

# Split the dataset into training (80%) and testing (20%)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_onehot, test_size=0.2, random_state=42)

# Create the DNN model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # 3 classes in the iris dataset, but it deepends, remember is a classifierer
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_test, y_test))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss on test set: {loss}')
print(f'Accuracy on test set: {accuracy}')

# %% [markdown]
# ### CNN

# %% [markdown]
# #### 50% Testing & 50% Training

# %%
from keras.optimizers import Adam
# load the iris dataset
iris_data = load_iris()

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)

# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.50)

# Build the model

model = Sequential()

model.add(Dense(10, input_shape=(4,), activation='relu', name='Dense-1'))
model.add(Dense(10, activation='relu', name='Dense-2'))
model.add(Dense(3, activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=100)
#notes, the CNN requieres more epochs to get a better classification

# Test on unseen data

results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))

# %%
model_matrix(model)

# %% [markdown]
# #### 20% Testing & 80% Training

# %%
from keras.optimizers import Adam
# load the iris dataset
iris_data = load_iris()

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)

# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# Build the model

model = Sequential()

model.add(Dense(10, input_shape=(4,), activation='relu', name='Dense-1'))
model.add(Dense(10, activation='relu', name='Dense-2'))
model.add(Dense(3, activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=100)

# Test on unseen data

results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))

# %%
model_matrix(model)

# %%
from sklearn.datasets import load_iris
import numpy
import pandas
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score

# %% [markdown]
# ### PNN

# %% [markdown]
# #### 20% Testing & 80% Training

# %%
iris = load_iris();
data = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target']);

# %%
# Standardise input and split into train and test sets
X = data.drop(columns='target',axis=1);
Y = data[['target']]
scaler = StandardScaler();
X_scaled = scaler.fit_transform(X);

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.8,random_state=12);

# %%
#Kernel functions
uniform = lambda x,b: (np.abs(x/b) <= 1) and 1/2 or 0
triangle = lambda x,b: (np.abs(x/b) <= 1) and  (1 - np.abs(x/b)) or 0
gaussian = lambda x,b: (1.0/np.sqrt(2*np.pi))* np.exp(-.5*(x/b)**2)
laplacian = lambda x,b: (1.0/(2*b))* np.exp(-np.abs(x/b))
epanechnikov = lambda x,b: (np.abs(x/b)<=1) and ((3/4)*(1-(x/b)**2)) or 0

# %%
def pattern_layer(inp,kernel,sigma):
  k_values=[];
  for i,p in enumerate(X_train.values):
    edis = np.linalg.norm(p-inp); #find eucliden distance
    k = kernel(edis,sigma); #pass values of euclidean dist and
    #smoothing parameter to kernel function
    k_values.append(k);
  return k_values;

# %%
def summation_layer(k_values,Y_train,class_counts):
  # Summing up each value for each class and then averaging
  summed =[0,0,0];
  for i,c in enumerate(class_counts):
    val = (Y_train['target']==class_counts.index[i]).values;
    k_values = np.array(k_values);
    summed[i] = np.sum(k_values[val]);


  avg_sum = list(summed/Y_train.value_counts());
  return avg_sum

# %%
def output_layer(avg_sum,class_counts):#OUTPUT LAYER
  maxv = max(avg_sum);
  label = class_counts.index[avg_sum.index(maxv)][0];

  return label

# %%
def pnn(X_train,Y_train,X_test,kernel,sigma):
  # Initialising variables
  class_counts = Y_train.value_counts()
  labels=[];
  #Passing each sample observation
  for s in X_test.values:
    k_values = pattern_layer(s,kernel,sigma);
    avg_sum = summation_layer(k_values,Y_train,class_counts);
    label = output_layer(avg_sum,class_counts);
    labels.append(label);
  print('Labels Generated for bandwidth:',sigma);
  return labels;

# %%
#Candidate Kernels
kernels = ['Gaussian','Triangular','Epanechnikov'];
sigmas = [0.05,0.5,0.8,1,1.2];

results = pd.DataFrame(columns=['Kernel','Smoothing Param','Accuracy','F1-Score']);
for k in kernels:
  if k=='Gaussian':
    k_func = gaussian;
  elif k=='Triangular':
    k_func = triangle;
  else:
    k_func = epanechnikov;

  for b in sigmas:
    pred = pnn(X_train,Y_train,X_test,k_func,b);
    accuracy = accuracy_score(Y_test.values,pred);
    f1= f1_score(Y_test.values,pred,average='weighted')
    results.loc[len(results.index)]=[k,b,accuracy,f1];
# Out:
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.subplot(121)
sns.lineplot(y=results['Accuracy'],x=results['Smoothing Param'],hue=results['Kernel']);
plt.title('Accuracy for Different Kernels',loc='right');

plt.subplot(122)
sns.lineplot(y=results['F1-Score'],x=results['Smoothing Param'],hue=results['Kernel']);
plt.title('F1-Score for Different Kernels',loc='left');

plt.show()

# %% [markdown]
# #### 50% Testing & 50% Training

# %%
# Standardise input and split into train and test sets
X = data.drop(columns='target',axis=1);
Y = data[['target']]
scaler = StandardScaler();
X_scaled = scaler.fit_transform(X);

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.5,random_state=12);

# %%
#Kernel functions
uniform = lambda x,b: (np.abs(x/b) <= 1) and 1/2 or 0
triangle = lambda x,b: (np.abs(x/b) <= 1) and  (1 - np.abs(x/b)) or 0
gaussian = lambda x,b: (1.0/np.sqrt(2*np.pi))* np.exp(-.5*(x/b)**2)
laplacian = lambda x,b: (1.0/(2*b))* np.exp(-np.abs(x/b))
epanechnikov = lambda x,b: (np.abs(x/b)<=1) and ((3/4)*(1-(x/b)**2)) or 0

# %%
#Candidate Kernels
kernels = ['Gaussian','Triangular','Epanechnikov'];
sigmas = [0.05,0.5,0.8,1,1.2];

results = pd.DataFrame(columns=['Kernel','Smoothing Param','Accuracy','F1-Score']);
for k in kernels:
  if k=='Gaussian':
    k_func = gaussian;
  elif k=='Triangular':
    k_func = triangle;
  else:
    k_func = epanechnikov;

  for b in sigmas:
    pred = pnn(X_train,Y_train,X_test,k_func,b);
    accuracy = accuracy_score(Y_test.values,pred);
    f1= f1_score(Y_test.values,pred,average='weighted')
    results.loc[len(results.index)]=[k,b,accuracy,f1];
# Out:
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2
# Labels Generated for bandwidth: 0.05
# Labels Generated for bandwidth: 0.5
# Labels Generated for bandwidth: 0.8
# Labels Generated for bandwidth: 1
# Labels Generated for bandwidth: 1.2

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.subplot(121)
sns.lineplot(y=results['Accuracy'],x=results['Smoothing Param'],hue=results['Kernel']);
plt.title('Accuracy for Different Kernels',loc='right');

plt.subplot(122)
sns.lineplot(y=results['F1-Score'],x=results['Smoothing Param'],hue=results['Kernel']);
plt.title('F1-Score for Different Kernels',loc='left');

plt.show()

# %% [markdown]
# The confusion Matrix show interesting things in the different classes of the models, I am not sure about the Wine ones, but for now are in process...

# %% [markdown]
# # **Conclusions**
# The differente processes were easy to implement but the differetn ways that the problem could take or the correct aplication of the posible variables for the functions are too much, so the posibles ways to take and measure the accuracy could be better or worse. But the most precisse until nwo is the Deep Neuronal Network, and even them if we change the parameters could be better or worse, and the epochs are one of the most imporntant things here. Like a Note, the CNN requieres more epohcs nd is not the best to classify non-images data.

# %% [markdown]
# ### References
# 1. KrishnaswamyLab. (s.f.). Introducción a la manipulación de datos mediante manifold learning. Google Colab Notebooks. Recuperado de https://colab.research.google.com/github/KrishnaswamyLab/SingleCellWorkshop/blob/master/exercises/Introduction_to_Manifold_Learing/notebooks/00_Answers_Plotting_UCI_wine.ipynb#scrollTo=pRzgHaB6GPRl
# 2. Daniyal9538. (s.f.). Decision Tree Tutorial. Google Colab Notebooks. Recuperado de https://colab.research.google.com/github/daniyal9538/GeneralProjects/blob/master/Decision_Tree_Tutorial.ipynb
# 3. VanderPlas/Jackevdp, J. (2020). Naive Bayes. Python Data Science Handbook. Recuperado de https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/05.05-Naive-Bayes.ipynb
# 4. Akshayrb22. (s.f.). K-Nearest Neighbors (KNN). Google Colab Notebooks. Recuperado de https://colab.research.google.com/github/akshayrb22/playing-with-data/blob/master/supervised_learning/KNN/KNN.ipynb
# 5. Ferro, R., & Alves, T. (s.f.). Iris Classification Problem. Google Colab Notebooks. Recuperado de https://colab.research.google.com/github/RodolfoFerro/RIIAA19-DLaaS/blob/master/notebooks/Iris%20Classification%20Problem.ipynb
# 6. SVM Exercise. Iris Exercise. Scikit-learn. Recuperado de https://scikit-learn.org/stable/auto_examples/exercises/plot_iris_exercise.html
# 7. Decision Trees. IBM. Recuperado de https://www.ibm.com/topics/decision-trees#:~:text=A%20decision%20tree%20is%20a,internal%20nodes%20and%20leaf%20nodes
# 8. Naïve Bayes classifiers. IBM. Recuperado de https://www.ibm.com/topics/naive-bayes#:~:text=the%20next%20step-,Na%C3%AFve%20Bayes%20classifiers,a%20given%20class%20or%20category.
# 9. What is the KNN algorithm?. IBM. Recuperado de https://www.ibm.com/topics/knn#:~:text=The%20k%2Dnearest%20neighbors%20(KNN)%20algorithm%20is%20a%20non,used%20in%20machine%20learning%20today.
# 10. RBF SVM parameters. Scikit-Learn. Recuperado de https://scikit-learn.org/stable/auto_examples/svm/plot_rbf_parameters.html#sphx-glr-auto-examples-svm-plot-rbf-parameters-py
# 11. Fred Tabsharani. Support Vector Machine (SVM). TechTarget. Recuperado de https://www.techtarget.com/whatis/definition/support-vector-machine-SVM#:~:text=A%20support%20vector%20machine%20(SVM)%20is%20a%20type%20of%20supervised,data%20set%20into%20two%20groups.
# 12. DataCamp & Bharath K. (2023, July). Introduction to Deep Neural Networks. DataCamp. https://www.datacamp.com/tutorial/introduction-to-deep-neural-networks
# 13. Analytics Vidhya. (2021, May 1). Introduction to Convolutional Neural Networks (CNN). Retrieved from https://www.analyticsvidhya.com/blog/2021/05/convolutional-neural-networks-cnn/
# 14. Analytics Vidhya. (2023, April 1). Bayesian Networks - Probabilistic Neural Network (PNN). Retrieved from https://www.analyticsvidhya.com/blog/2023/04/bayesian-networks-probabilistic-neural-network-pnn/
#
#
#
# Note: Most of this code were review by an AI.
